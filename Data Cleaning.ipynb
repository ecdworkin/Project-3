# %%
#Zip codes for consideration: 89143, 89166,89149, 89131, 89130, 89129, 89108, 89138, 89134, 89144, 89128, 89145, 
#89107, 89106, 89101, 89110, 89156, 89115, 89030, 89032, 89031, 89081, 89086, 89084, 89085, 89135, 89117, 
#89146, 89102, 89104, 89142, 89122, 89121, 89169, 89119, 89109, 89158, 89103, 89147, 89148, 89178, 89179, 89141,
#89139, 89113, 89139, 89118, 89183, 89123, 89120, 89044, 89052, 89012, 89074, 89014, 89011, 89015, 89002

# %%
import pandas as pd

# %%
vegas_zips = {
    '89143': 'Las Vegas',
    '89166': 'Las Vegas',
    '89149': 'Las Vegas',
    '89131': 'Las Vegas',
    '89130': 'Las Vegas',
    '89129': 'Las Vegas',
    '89108': 'Las Vegas',
    '89138': 'Las Vegas',
    '89134': 'Las Vegas',
    '89144': 'Las Vegas',
    '89128': 'Las Vegas',
    '89145': 'Las Vegas',
    '89107': 'Las Vegas',
    '89106': 'Las Vegas',
    '89101': 'Las Vegas',
    '89110': 'Las Vegas',
    '89156': 'Las Vegas',
    '89115': 'Las Vegas',
    '89030': 'Las Vegas',
    '89032': 'Las Vegas',
    '89031': 'Las Vegas',
    '89081': 'Las Vegas',
    '89086': 'Las Vegas',
    '89084': 'Las Vegas',
    '89085': 'Las Vegas',
    '89135': 'Las Vegas',
    '89117': 'Las Vegas',
    '89146': 'Las Vegas',
    '89102': 'Las Vegas',
    '89104': 'Las Vegas',
    '89142': 'Las Vegas',
    '89122': 'Las Vegas',
    '89121': 'Las Vegas',
    '89169': 'Las Vegas',
    '89119': 'Las Vegas',
    '89109': 'Las Vegas',
    '89158': 'Las Vegas',
    '89103': 'Las Vegas',
    '89147': 'Las Vegas',
    '89148': 'Las Vegas',
    '89178': 'Las Vegas',
    '89179': 'Las Vegas',
    '89141': 'Las Vegas',
    '89139': 'Las Vegas',
    '89113': 'Las Vegas',
    '89118': 'Las Vegas',
    '89183': 'Las Vegas',
    '89123': 'Las Vegas',
    '89120': 'Las Vegas',
    '89044': 'Las Vegas',
    '89052': 'Las Vegas',
    '89012': 'Las Vegas',
    '89074': 'Las Vegas',
    '89014': 'Las Vegas',
    '89011': 'Las Vegas',
    '89015': 'Las Vegas',
    '89002': 'Las Vegas'
}

# Convert the dictionary to a pandas DataFrame
vegas_zips_df = pd.DataFrame(list(zip(vegas_zips.keys(), vegas_zips.values())), columns=['Zip Code', 'Location'])

# Print the DataFrame
print(vegas_zips_df)
# Out:
#    Zip Code   Location
# 0     89143  Las Vegas
# 1     89166  Las Vegas
# 2     89149  Las Vegas
# 3     89131  Las Vegas
# 4     89130  Las Vegas
# 5     89129  Las Vegas
# 6     89108  Las Vegas
# 7     89138  Las Vegas
# 8     89134  Las Vegas
# 9     89144  Las Vegas
# 10    89128  Las Vegas
# 11    89145  Las Vegas
# 12    89107  Las Vegas
# 13    89106  Las Vegas
# 14    89101  Las Vegas
# 15    89110  Las Vegas
# 16    89156  Las Vegas
# 17    89115  Las Vegas
# 18    89030  Las Vegas
# 19    89032  Las Vegas
# 20    89031  Las Vegas
# 21    89081  Las Vegas
# 22    89165  Las Vegas
# 23    89086  Las Vegas
# 24    89084  Las Vegas
# 25    89085  Las Vegas
# 26    89087  Las Vegas
# 27    89135  Las Vegas
# 28    89117  Las Vegas
# 29    89146  Las Vegas
# 30    89102  Las Vegas
# 31    89104  Las Vegas
# 32    89142  Las Vegas
# 33    89122  Las Vegas
# 34    89121  Las Vegas
# 35    89169  Las Vegas
# 36    89119  Las Vegas
# 37    89109  Las Vegas
# 38    89158  Las Vegas
# ...
