# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
home_values_path = "Resources/home_values_by_zip.csv"
zip_codes_path = "Resources/zip_codes.csv"

# Read the mouse data and the study results
home_values_df = pd.read_csv(home_values_path)
zip_codes_df = pd.read_csv(zip_codes_path)

# Combine the data into a single DataFrame
#mouse_study_combined_df = pd.merge(study_results, mouse_metadata, on="Mouse ID", how="left")

# Display the data table for preview
home_values_df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91982         1       77494        zip        TX    TX      Katy
# 1     61148         2        8701        zip        NJ    NJ  Lakewood
# 2     91940         3       77449        zip        TX    TX      Katy
# 3     62080         4       11368        zip        NY    NY  New York
# 4     91733         5       77084        zip        TX    TX   Houston
#
#                                    Metro        CountyName     2000-01-31  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  207485.703780
# 1  New York-Newark-Jersey City, NY-NJ-PA      Ocean County  133585.097374
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County  102871.872959
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County  149602.706723
# 4   Houston-The Woodlands-Sugar Land, TX     Harris County  101302.971510
#
#    ...     2023-04-30     2023-05-31     2023-06-30     2023-07-31  \
# ...

# %%
zip_codes_df
# Out:
#     Zip Code   Location
# 0      89143  Las Vegas
# 1      89166  Las Vegas
# 2      89149  Las Vegas
# 3      89131  Las Vegas
# 4      89130  Las Vegas
# 5      89129  Las Vegas
# 6      89108  Las Vegas
# 7      89138  Las Vegas
# 8      89134  Las Vegas
# 9      89144  Las Vegas
# 10     89128  Las Vegas
# 11     89145  Las Vegas
# 12     89107  Las Vegas
# 13     89106  Las Vegas
# 14     89101  Las Vegas
# 15     89110  Las Vegas
# 16     89156  Las Vegas
# 17     89115  Las Vegas
# 18     89030  Las Vegas
# 19     89032  Las Vegas
# 20     89031  Las Vegas
# 21     89081  Las Vegas
# 22     89165  Las Vegas
# 23     89086  Las Vegas
# 24     89084  Las Vegas
# 25     89085  Las Vegas
# 26     89087  Las Vegas
# 27     89135  Las Vegas
# 28     89117  Las Vegas
# 29     89146  Las Vegas
# 30     89102  Las Vegas
# 31     89104  Las Vegas
# 32     89142  Las Vegas
# 33     89122  Las Vegas
# 34     89121  Las Vegas
# 35     89169  Las Vegas
# 36     89119  Las Vegas
# ...

# %%
renamed_zip_codes_df = zip_codes_df.rename(columns={'Zip Code': 'ZipCode'})
renamed_home_values_df = home_values_df.rename(columns={'RegionName': 'ZipCode'})

# %%
renamed_zip_codes_df.head()
# Out:
#    ZipCode   Location
# 0    89143  Las Vegas
# 1    89166  Las Vegas
# 2    89149  Las Vegas
# 3    89131  Las Vegas
# 4    89130  Las Vegas

# %%
renamed_home_values_df.head()
# Out:
#    RegionID  SizeRank  ZipCode RegionType StateName State      City  \
# 0     91982         1    77494        zip        TX    TX      Katy
# 1     61148         2     8701        zip        NJ    NJ  Lakewood
# 2     91940         3    77449        zip        TX    TX      Katy
# 3     62080         4    11368        zip        NY    NY  New York
# 4     91733         5    77084        zip        TX    TX   Houston
#
#                                    Metro        CountyName     2000-01-31  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  207485.703780
# 1  New York-Newark-Jersey City, NY-NJ-PA      Ocean County  133585.097374
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County  102871.872959
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County  149602.706723
# 4   Houston-The Woodlands-Sugar Land, TX     Harris County  101302.971510
#
#    ...     2023-04-30     2023-05-31     2023-06-30     2023-07-31  \
# ...

# %%
merged_df = pd.merge(renamed_home_values_df, renamed_zip_codes_df, on='ZipCode', how='inner')
merged_df
# Out:
#     RegionID  SizeRank  ZipCode RegionType StateName State             City  \
# 0      95804       162    89108        zip        NV    NV        Las Vegas
# 1      95770       198    89031        zip        NV    NV  North Las Vegas
# 2      95811       261    89115        zip        NV    NV        Las Vegas
# 3      95817       280    89121        zip        NV    NV        Las Vegas
# 4      95806       292    89110        zip        NV    NV        Las Vegas
# 5      95819       384    89123        zip        NV    NV        Las Vegas
# 6      95844       413    89148        zip        NV    NV        Las Vegas
# 7      95785       609    89052        zip        NV    NV        Henderson
# 8      95825       616    89129        zip        NV    NV        Las Vegas
# 9      95843       668    89147        zip        NV    NV        Las Vegas
# 10     95813       718    89117        zip        NV    NV        Las Vegas
# ...

# %%
home_values_latest_df = pd.DataFrame({"ZipCode": merged_df['ZipCode'], 
                                   "City": merged_df['City'],  
                                   "State": merged_df['State'],
                                   '2019-01-31': merged_df['2019-01-31'],
                                   '2019-02-28': merged_df['2019-02-28'], 
                                   '2019-03-31': merged_df['2019-03-31'],
                                   '2019-04-30': merged_df['2019-04-30'],
                                   '2019-05-31': merged_df['2019-05-31'],
                                   '2019-06-30': merged_df['2019-06-30'],
                                   '2019-07-31': merged_df['2019-07-31'],
                                   '2019-08-31': merged_df['2019-08-31'],
                                   '2019-09-30': merged_df['2019-09-30'],
                                   '2019-10-31': merged_df['2019-10-31'],
                                   '2019-11-30': merged_df['2019-11-30'],
                                   '2019-12-31': merged_df['2019-12-31'],                                
                                   '2020-01-31': merged_df['2020-01-31'],
                                   '2020-02-29': merged_df['2020-02-29'], 
                                   '2020-03-31': merged_df['2020-03-31'],
                                   '2020-04-30': merged_df['2020-04-30'],
                                   '2020-05-31': merged_df['2020-05-31'],
                                   '2020-06-30': merged_df['2020-06-30'],
                                   '2020-07-31': merged_df['2020-07-31'],
                                   '2020-08-31': merged_df['2020-08-31'],
                                   '2020-09-30': merged_df['2020-09-30'],
                                   '2020-10-31': merged_df['2020-10-31'],
                                   '2020-11-30': merged_df['2020-11-30'],
                                   '2020-12-31': merged_df['2020-12-31'],                                
                                   '2021-01-31': merged_df['2021-01-31'],
                                   '2021-02-28': merged_df['2021-02-28'], 
                                   '2021-03-31': merged_df['2021-03-31'],
                                   '2021-04-30': merged_df['2021-04-30'],
                                   '2021-05-31': merged_df['2021-05-31'],
                                   '2021-06-30': merged_df['2021-06-30'],
                                   '2021-07-31': merged_df['2021-07-31'],
                                   '2021-08-31': merged_df['2021-08-31'],
                                   '2021-09-30': merged_df['2021-09-30'],
                                   '2021-10-31': merged_df['2021-10-31'],
                                   '2021-11-30': merged_df['2021-11-30'],
                                   '2021-12-31': merged_df['2021-12-31'],                                
                                   '2022-01-31': merged_df['2022-01-31'],
                                   '2022-02-28': merged_df['2022-02-28'], 
                                   '2022-03-31': merged_df['2022-03-31'],
                                   '2022-04-30': merged_df['2022-04-30'],
                                   '2022-05-31': merged_df['2022-05-31'],
                                   '2022-06-30': merged_df['2022-06-30'],
                                   '2022-07-31': merged_df['2022-07-31'],
                                   '2022-08-31': merged_df['2022-08-31'],
                                   '2022-09-30': merged_df['2022-09-30'],
                                   '2022-10-31': merged_df['2022-10-31'],
                                   '2022-11-30': merged_df['2022-11-30'],
                                   '2022-12-31': merged_df['2022-12-31'],                                
                                   '2023-01-31': merged_df['2023-01-31'],
                                   '2023-02-28': merged_df['2023-02-28'], 
                                   '2023-03-31': merged_df['2023-03-31'],
                                   '2023-04-30': merged_df['2023-04-30'],
                                   '2023-05-31': merged_df['2023-05-31'],
                                   '2023-06-30': merged_df['2023-06-30'],
                                   '2023-07-31': merged_df['2023-07-31'],
                                   '2023-08-31': merged_df['2023-08-31'],
                                   '2023-09-30': merged_df['2023-09-30'],
                                   '2023-10-31': merged_df['2023-10-31'],
                                   '2023-11-30': merged_df['2023-11-30'],
                                   '2023-12-31': merged_df['2023-12-31']})

home_values_latest_df
# Out:
#     ZipCode             City State     2019-01-31     2019-02-28  \
# 0     89108        Las Vegas    NV  225724.498411  227073.591655
# 1     89031  North Las Vegas    NV  265458.885228  266957.769390
# 2     89115        Las Vegas    NV  201921.648676  203203.525008
# 3     89121        Las Vegas    NV  225425.458660  226497.796598
# 4     89110        Las Vegas    NV  222298.616250  223712.135768
# 5     89123        Las Vegas    NV  294260.314682  295334.654555
# 6     89148        Las Vegas    NV  320724.976510  321946.235663
# 7     89052        Henderson    NV  399826.866015  401125.320950
# 8     89129        Las Vegas    NV  294883.765184  296304.093169
# 9     89147        Las Vegas    NV  276708.960420  277809.046295
# 10    89117        Las Vegas    NV  316063.356842  317134.233354
# 11    89074        Henderson    NV  308101.913765  309310.409400
# 12    89030  North Las Vegas    NV  178166.174265  179945.699784
# ...

# %%
values_df = home_values_latest_df.drop(columns=["City", "State"])
values_df
# Out:
#     ZipCode     2019-01-31     2019-02-28     2019-03-31     2019-04-30  \
# 0     89108  225724.498411  227073.591655  228137.666271  228997.442154
# 1     89031  265458.885228  266957.769390  268404.629140  269670.170977
# 2     89115  201921.648676  203203.525008  203937.849341  204464.417174
# 3     89121  225425.458660  226497.796598  227371.781901  228039.795332
# 4     89110  222298.616250  223712.135768  224957.442032  225835.060338
# 5     89123  294260.314682  295334.654555  296540.810691  297463.171464
# 6     89148  320724.976510  321946.235663  323243.294836  324194.870672
# 7     89052  399826.866015  401125.320950  402510.746554  403711.460484
# 8     89129  294883.765184  296304.093169  297711.228798  298787.505071
# 9     89147  276708.960420  277809.046295  279005.317798  280061.913805
# 10    89117  316063.356842  317134.233354  318101.619427  318696.320549
# 11    89074  308101.913765  309310.409400  310492.283531  311385.681832
# ...

# %%
df_long = pd.melt(values_df, id_vars=['ZipCode'], var_name='Date', value_name='Value')
df_long
# Out:
#       ZipCode        Date          Value
# 0       89108  2019-01-31  225724.498411
# 1       89031  2019-01-31  265458.885228
# 2       89115  2019-01-31  201921.648676
# 3       89121  2019-01-31  225425.458660
# 4       89110  2019-01-31  222298.616250
# ...       ...         ...            ...
# 3415    89179  2023-12-31  449816.239219
# 3416    89086  2023-12-31  407944.998991
# 3417    89109  2023-12-31  376390.038050
# 3418    89085  2023-12-31  481669.814364
# 3419    89158  2023-12-31  541563.044351
#
# [3420 rows x 3 columns]

# %%
df_long.to_csv('Resources/las_vegas_home_values_by_zip_codes.csv', index = False)

# %%
# List of columns to keep
columns_to_keep = ['ZipCode', 'City', 'State']

# Drop columns except for the specified ones
city_df = home_values_latest_df[columns_to_keep]

city_df
# Out:
#     ZipCode             City State
# 0     89108        Las Vegas    NV
# 1     89031  North Las Vegas    NV
# 2     89115        Las Vegas    NV
# 3     89121        Las Vegas    NV
# 4     89110        Las Vegas    NV
# 5     89123        Las Vegas    NV
# 6     89148        Las Vegas    NV
# 7     89052        Henderson    NV
# 8     89129        Las Vegas    NV
# 9     89147        Las Vegas    NV
# 10    89117        Las Vegas    NV
# 11    89074        Henderson    NV
# 12    89030  North Las Vegas    NV
# 13    89103        Las Vegas    NV
# 14    89131        Las Vegas    NV
# 15    89119        Las Vegas    NV
# 16    89122        Las Vegas    NV
# 17    89032  North Las Vegas    NV
# 18    89015        Henderson    NV
# 19    89101        Las Vegas    NV
# 20    89139        Las Vegas    NV
# 21    89149        Las Vegas    NV
# 22    89183        Las Vegas    NV
# 23    89014        Henderson    NV
# 24    89104        Las Vegas    NV
# 25    89128        Las Vegas    NV
# ...

# %%
city_df.to_csv('Resources/cities_zip_codes.csv', index = False)

# %%
vegas_merged_df = pd.merge(df_long, city_df, on='ZipCode', how='left')
vegas_merged_df
# Out:
#       ZipCode        Date          Value             City State
# 0       89108  2019-01-31  225724.498411        Las Vegas    NV
# 1       89031  2019-01-31  265458.885228  North Las Vegas    NV
# 2       89115  2019-01-31  201921.648676        Las Vegas    NV
# 3       89121  2019-01-31  225425.458660        Las Vegas    NV
# 4       89110  2019-01-31  222298.616250        Las Vegas    NV
# ...       ...         ...            ...              ...   ...
# 3415    89179  2023-12-31  449816.239219        Las Vegas    NV
# 3416    89086  2023-12-31  407944.998991  North Las Vegas    NV
# 3417    89109  2023-12-31  376390.038050        Las Vegas    NV
# 3418    89085  2023-12-31  481669.814364  North Las Vegas    NV
# 3419    89158  2023-12-31  541563.044351        Las Vegas    NV
#
# [3420 rows x 5 columns]

# %%
vegas_merged_df.to_csv('Resources/vegas_home_values_zip_codes.csv', index = False)
