# %%
import requests
from datetime import datetime
import time

# Define the URL of the API endpoint
url = "https://api.crimeometer.com/v1/incidents/stats"

# Define the query parameters
params = {
    "lat": "36.1716",
    "lon": "-115.1391",
    "distance": "20mi",
    "datetime_ini": datetime.strftime(datetime(2023, 1, 1, 1, 0, 0), '%Y-%m-%dT%H:%M:%S.000Z'),
    "datetime_end": datetime.strftime(datetime(2023, 12, 31, 23, 59, 0), '%Y-%m-%dT%H:%M:%S.000Z'),
    "page": "1"
    #"source": "0"
}
# Define the headers with the API key
headers = {
    "x-api-key": "1byzWHeJz43SYSY7E89bWTR8zxM5e3T9NRE67U70"
}

for page in range(2,11):
    final_url = f'https://api.crimeometer.com/v1/incidents/raw-data?lat={params["lat"]}&lon={params["lon"]}&datetime_ini=2022-10-01 00:00:00&datetime_end=2022-12-31 00:00:00&distance={params["distance"]}&page={page}'
    # Make the GET request to the API
    response = requests.get(final_url, headers=headers)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        print(response)
        # Extract and print the JSON data from the response
        data = response.json()
        print(data)
    elif response.status_code == 429:
        # If rate limit exceeded, wait for some time and retry
       # retry_after = int(response.headers.get('Retry-After', 10))  # Default to waiting for 10 seconds
        print(f"Rate limit exceeded. Waiting for {retry_after} seconds before retrying...")
       # time.sleep(retry_after)
        # Retry the request
       # response = requests.get(url, params=params, headers=headers)
        # Handle the response as needed
        # ...
    else:
        # If the request was unsuccessful for other reasons, print an error message
        print("Error:", response.status_code)
# Out:
# <Response [200]>
# {'total_incidents': 28329, 'total_pages': 284, 'incidents': [{'city_key': 'LAS', 'incident_code': 'LLV230199999806', 'incident_date': '2022-12-30T23:52:00Z', 'incident_offense': 'Larceny/Theft Offenses', 'incident_offense_code': '23F', 'incident_offense_description': 'Theft From Motor Vehicle', 'incident_offense_detail_description': 'Theft From Motor Vehicle at 6800 Block S LAS VEGAS BLVD LAS VEGAS, NV 89119', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Theft From Motor Vehicle', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.06516, 'incident_longitude': -115.1732925, 'incident_address': '6800 Block S LAS VEGAS BLVD LAS VEGAS, NV 89119'}, {'city_key': 'LAS', 'incident_code': 'LLV221200120737', 'incident_date': '2022-12-30T23:51:00Z', 'incident_offense': 'Drug/Narcotic Offenses', 'incident_offense_code': '35A', 'incident_offense_description': 'Drug/Narcotic Violations', 'incident_offense_detail_description': 'Drug/Narcotic Violations at 5000 Block S JONES BLVD LAS VEGAS, NV  89118', 'incident_offense_crime_against': 'Society', 'incident_offense_action': 'C', 'incident_source_original_type': 'Drug/narcotic Violations', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.097578, 'incident_longitude': -115.2244215, 'incident_address': '5000 Block S JONES BLVD LAS VEGAS, NV  89118'}, {'city_key': 'LAS', 'incident_code': 'LLV221200120702', 'incident_date': '2022-12-30T23:43:25Z', 'incident_offense': 'Motor Vehicle Theft', 'incident_offense_code': '240', 'incident_offense_description': 'Motor Vehicle Theft', 'incident_offense_detail_description': 'Motor Vehicle Theft at 2600 Block S NELLIS BLVD LAS VEGAS, NV  89104', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Motor Vehicle Theft', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.141219, 'incident_longitude': -115.068582, 'incident_address': '2600 Block S NELLIS BLVD LAS VEGAS, NV  89104'}, {'city_key': 'LAS', 'incident_code': 'LLV230199999994', 'incident_date': '2022-12-30T23:43:09Z', 'incident_offense': 'Larceny/Theft Offenses', 'incident_offense_code': '23C', 'incident_offense_description': 'Shoplifting', 'incident_offense_detail_description': 'Shoplifting at 10000 Block W SAHARA AVE Las Vegas, NV 89117', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Shoplifting', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.145548, 'incident_longitude': -115.313058, 'incident_address': '10000 Block W SAHARA AVE Las Vegas, NV 89117'}, {'city_key': 'LAS', 'incident_code': 'LLV221200120698', 'incident_date': '2022-12-30T23:42:05Z', 'incident_offense': 'Assault Offenses', 'incident_offense_code': '13B', 'incident_offense_description': 'Simple Assault', 'incident_offense_detail_description': 'Simple Assault at 8700 Block MOHER CLIFFS CIR Las Vegas, NV  89148', 'incident_offense_crime_against': 'Person', 'incident_offense_action': 'C', 'incident_source_original_type': 'Simple Assault', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.074277, 'incident_longitude': -115.2818595, 'incident_address': '8700 Block MOHER CLIFFS CIR Las Vegas, NV  89148'}, {'city_key': 'LAS', 'incident_code': 'LLV221200120081', 'incident_date': '2022-12-30T23:40:00Z', 'incident_offense': 'Drug/Narcotic Offenses', 'incident_offense_code': '35A', 'incident_offense_description': 'Drug/Narcotic Violations', 'incident_offense_detail_description': 'Drug/Narcotic Violations at E Twain Ave & Boulder Hwy Las Vegas, NV  89121', 'incident_offense_crime_against': 'Society', 'incident_offense_action': 'C', 'incident_source_original_type': 'Drug/narcotic Violations', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.123156, 'incident_longitude': -115.076043, 'inci ...

# %%
crime_list = []
