# %%
import requests
from datetime import datetime
import time
import plotly

# Define the URL of the API endpoint
url = "https://api.crimeometer.com/v1/incidents/stats"

# Define the query parameters
params = {
    "lat": "36.1716",
    "lon": "-115.1391",
    "distance": "20mi",
    "datetime_ini": datetime.strftime(datetime(2023, 1, 1, 1, 0, 0), '%Y-%m-%dT%H:%M:%S.000Z'),
    "datetime_end": datetime.strftime(datetime(2023, 12, 31, 23, 59, 0), '%Y-%m-%dT%H:%M:%S.000Z'),
    "page": "1"
    #"source": "0"
}
# Define the headers with the API key
headers = {
    "x-api-key": "1byzWHeJz43SYSY7E89bWTR8zxM5e3T9NRE67U70"
}

for page in range(2,11):
    final_url = f'https://api.crimeometer.com/v1/incidents/raw-data?lat={params["lat"]}&lon={params["lon"]}&datetime_ini=2022-10-01 00:00:00&datetime_end=2022-12-31 00:00:00&distance={params["distance"]}&page={page}'
    # Make the GET request to the API
    response = requests.get(final_url, headers=headers)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        print(response)
        # Extract and print the JSON data from the response
        data = response.json()
        print(data)
    elif response.status_code == 429:
        # If rate limit exceeded, wait for some time and retry
       # retry_after = int(response.headers.get('Retry-After', 10))  # Default to waiting for 10 seconds
        print(f"Rate limit exceeded. Waiting for {retry_after} seconds before retrying...")
       # time.sleep(retry_after)
        # Retry the request
       # response = requests.get(url, params=params, headers=headers)
        # Handle the response as needed
        # ...
    else:
        # If the request was unsuccessful for other reasons, print an error message
        print("Error:", response.status_code)
# Out:
# <Response [200]>
# {'total_incidents': 28329, 'total_pages': 284, 'incidents': [{'city_key': 'LAS', 'incident_code': 'LLV221200118798', 'incident_date': '2022-12-30T17:10:00Z', 'incident_offense': 'Assault Offenses', 'incident_offense_code': '13A', 'incident_offense_description': 'Aggravated Assault', 'incident_offense_detail_description': 'Aggravated Assault at 2600 Block E SUNSET RD Las Vegas, NV  89120', 'incident_offense_crime_against': 'Person', 'incident_offense_action': 'C', 'incident_source_original_type': 'Aggravated Assault', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.067806, 'incident_longitude': -115.114131, 'incident_address': '2600 Block E SUNSET RD Las Vegas, NV  89120'}, {'city_key': 'LAS', 'incident_code': 'LLV221299999005', 'incident_date': '2022-12-30T17:05:07Z', 'incident_offense': 'Destruction/Damage/Vandalism of Property', 'incident_offense_code': '290', 'incident_offense_description': 'Destruction/Damage/Vandalism of Property', 'incident_offense_detail_description': 'Destruction/Damage/Vandalism of Property at 3300 Block S LAS VEGAS BLVD LAS VEGAS, NV 89109', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Destruction/Damage/Vandalism of Property', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.124542, 'incident_longitude': -115.172334, 'incident_address': '3300 Block S LAS VEGAS BLVD LAS VEGAS, NV 89109'}, {'city_key': 'LAS', 'incident_code': 'LLV221200118775', 'incident_date': '2022-12-30T17:04:00Z', 'incident_offense': 'Assault Offenses', 'incident_offense_code': '13B', 'incident_offense_description': 'Simple Assault', 'incident_offense_detail_description': 'Simple Assault at 4800 Block E SAHARA AVE LV, NV  89121', 'incident_offense_crime_against': 'Person', 'incident_offense_action': 'C', 'incident_source_original_type': 'Simple Assault', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.143316, 'incident_longitude': -115.069212, 'incident_address': '4800 Block E SAHARA AVE LV, NV  89121'}, {'city_key': 'LAS', 'incident_code': 'LLV221200118415', 'incident_date': '2022-12-30T17:00:00Z', 'incident_offense': 'Burglary/Breaking & Entering', 'incident_offense_code': '220', 'incident_offense_description': 'Burglary/Breaking & Entering', 'incident_offense_detail_description': 'Burglary/Breaking & Entering at 7900 Block RAFAEL RIVERA WAY Lv, NV  89113', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Burglary/Breaking and Entering', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.067653, 'incident_longitude': -115.2635535, 'incident_address': '7900 Block RAFAEL RIVERA WAY Lv, NV  89113'}, {'city_key': 'LAS', 'incident_code': 'LLV230199999989', 'incident_date': '2022-12-30T16:57:20Z', 'incident_offense': 'Larceny/Theft Offenses', 'incident_offense_code': '23H', 'incident_offense_description': 'All Other Larceny', 'incident_offense_detail_description': 'All Other Larceny at 5200 Block GOLDEN LN LAS VEGAS, NV 89119', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'All Other Larceny', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.094599, 'incident_longitude': -115.1385525, 'incident_address': '5200 Block GOLDEN LN LAS VEGAS, NV 89119'}, {'city_key': 'LAS', 'incident_code': 'LLV230199999983', 'incident_date': '2022-12-30T16:54:14Z', 'incident_offense': 'Larceny/Theft Offenses', 'incident_offense_code': '23H', 'incident_offense_description': 'All Other Larceny', 'incident_offense_detail_description': 'All Other Larceny at S MARYLAND PKWY & E Flamingo Rd Las Vegas, NV  89119', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'All Other Larceny', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.114 ...
# <Response [200]>
# {'total_incidents': 28329, 'total_pages': 284, 'incidents': [{'city_key': 'LAS', 'incident_code': 'LLV221200117948', 'incident_date': '2022-12-30T13:04:44Z', 'incident_offense': 'Larceny/Theft Offenses', 'incident_offense_code': '23C', 'incident_offense_description': 'Shoplifting', 'incident_offense_detail_description': 'Shoplifting at 5600 Block Rickenbacker Rd NELLIS AFB, NV  89115', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Shoplifting', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.2357375, 'incident_longitude': -115.0500834, 'incident_address': '5600 Block Rickenbacker Rd NELLIS AFB, NV  89115'}, {'city_key': 'LAS', 'incident_code': 'LLV230199999962', 'incident_date': '2022-12-30T13:02:55Z', 'incident_offense': 'Larceny/Theft Offenses', 'incident_offense_code': '23C', 'incident_offense_description': 'Shoplifting', 'incident_offense_detail_description': 'Shoplifting at 7500 Block W WASHINGTON AVE Las Vegas, NV 89128', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Shoplifting', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.182403, 'incident_longitude': -115.257996, 'incident_address': '7500 Block W WASHINGTON AVE Las Vegas, NV 89128'}, {'city_key': 'LAS', 'incident_code': 'LLV221200117942', 'incident_date': '2022-12-30T13:02:36Z', 'incident_offense': 'Destruction/Damage/Vandalism of Property', 'incident_offense_code': '290', 'incident_offense_description': 'Destruction/Damage/Vandalism of Property', 'incident_offense_detail_description': 'Destruction/Damage/Vandalism of Property at 3500 Block S Maryland Pkwy LAS VEGAS, NV  89169', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Destruction/Damage/Vandalism of Property', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.1251025, 'incident_longitude': -115.1371397, 'incident_address': '3500 Block S Maryland Pkwy LAS VEGAS, NV  89169'}, {'city_key': 'LAS', 'incident_code': 'LLV221200117940', 'incident_date': '2022-12-30T13:01:50Z', 'incident_offense': 'Larceny/Theft Offenses', 'incident_offense_code': '23D', 'incident_offense_description': 'Theft From Building', 'incident_offense_detail_description': 'Theft From Building at 7300 Block S Buffalo Dr LAS VEGAS, NV  89113', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Theft From Building', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.0549817, 'incident_longitude': -115.2609768, 'incident_address': '7300 Block S Buffalo Dr LAS VEGAS, NV  89113'}, {'city_key': 'LAS', 'incident_code': 'LLV221200117937', 'incident_date': '2022-12-30T13:00:00Z', 'incident_offense': 'Destruction/Damage/Vandalism of Property', 'incident_offense_code': '290', 'incident_offense_description': 'Destruction/Damage/Vandalism of Property', 'incident_offense_detail_description': 'Destruction/Damage/Vandalism of Property at W Sahara Ave & S Fort Apache Rd Las Vegas, NV  89117', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Destruction/Damage/Vandalism of Property', 'incident_source_name': 'Las Vegas Police Department', 'incident_latitude': 36.1442765, 'incident_longitude': -115.2976721, 'incident_address': 'W Sahara Ave & S Fort Apache Rd Las Vegas, NV  89117'}, {'city_key': 'LAS', 'incident_code': 'LLV230199999963', 'incident_date': '2022-12-30T12:58:26Z', 'incident_offense': 'Larceny/Theft Offenses', 'incident_offense_code': '23C', 'incident_offense_description': 'Shoplifting', 'incident_offense_detail_description': 'Shoplifting at 7500 Block W WASHINGTON AVE Las Vegas, NV 89128', 'incident_offense_crime_against': 'Property', 'incident_offense_action': 'C', 'incident_source_original_type': 'Shoplifting', 'in ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 38
#      34     print(data)
#      35 elif response.status_code == 429:
#      36     # If rate limit exceeded, wait for some time and retry
#      37    # retry_after = int(response.headers.get('Retry-After', 10))  # Default to waiting for 10 seconds
# ---> 38     print(f"Rate limit exceeded. Waiting for {retry_after} seconds before retrying...")
#      39    # time.sleep(retry_after)
#      40     # Retry the request
#      41    # response = requests.get(url, params=params, headers=headers)
#    (...)
#      44 else:
#      45     # If the request was unsuccessful for other reasons, print an error message
#      46     print("Error:", response.status_code)
#
# NameError: name 'retry_after' is not defined

# %%
#Parse and Process Data
crime_data = pd.read_json("tiffc\Desktop\Bootcamp\Project 3\Project-3")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 #Parse and Process Data
# ----> 2 crime_data = pd.read_json("tiffc\Desktop\Bootcamp\Project 3\Project-3")
#
# NameError: name 'pd' is not defined

# %%
print(crime_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(crime_data)
#
# NameError: name 'crime_data' is not defined

# %%
    z=data['values'],
    x=data['x_labels'],
    y=data['y_labels'],
    colorscale='Viridis'))

# %%
heatmap.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 heatmap.show()
#
# NameError: name 'heatmap' is not defined
